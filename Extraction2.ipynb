# %%
#pip install wikipedia-api pandas requests
import wikipediaapi  # API pour accéder à Wikipedia
import pandas as pd  # Pour structurer les données
import requests  # Requêtes HTTP à l'API

# Initialisation de l'API Wikipedia avec un User-Agent personnalisé
user_agent = "GenderAnalysisProject/1.0 (contact@example.com)"  # Remplacez par votre email ou URL de contact
wiki = wikipediaapi.Wikipedia(language='en', user_agent=user_agent)  # Langue: anglais


# Fonction pour explorer une catégorie et ses sous-catégories pour obtenir les pages d'utilisateurs
def get_wikipedians_by_category(category_name):
    """
    Récupère une liste de contributeurs Wikipedia à partir d'une catégorie donnée, en parcourant les sous-catégories.
    :param category_name: Nom de la catégorie (par exemple, 'Female Wikipedians')
    :return: Liste des contributeurs
    """
    category = wiki.page(f"Category:{category_name}")
    wikipedians = []
    
    if category.exists():
        def process_category(cat):
            for member in cat.categorymembers.values():
                # Si la page est un utilisateur, on l'ajoute
                if member.ns == wikipediaapi.Namespace.USER:
                    wikipedians.append(member.title)
                # Si c'est une sous-catégorie, on la traite récursivement
                elif member.ns == wikipediaapi.Namespace.CATEGORY:
                    process_category(member)
                    
        process_category(category)
    else:
        print(f"La catégorie {category_name} n'existe pas.")
    
    return wikipedians

# Collecter les contributeurs des trois catégories
female_wikipedians = get_wikipedians_by_category("Female_Wikipedians")
male_wikipedians = get_wikipedians_by_category("Male_Wikipedians")
transgender_wikipedians = get_wikipedians_by_category("Transgender_Wikipedians")

# Affichage des résultats (10 premiers contributeurs pour chaque catégorie)
print(f"Contributeurs (Femmes): {female_wikipedians[:10]}")
print(f"Contributeurs (Hommes): {male_wikipedians[:10]}")
print(f"Contributeurs (Transgenres): {transgender_wikipedians[:10]}")

# Enregistrer les résultats dans des fichiers CSV
pd.DataFrame(female_wikipedians, columns=['Name']).to_csv("female_wikipedians.csv", index=False)
pd.DataFrame(male_wikipedians, columns=['Name']).to_csv("male_wikipedians.csv", index=False)
pd.DataFrame(transgender_wikipedians, columns=['Name']).to_csv("transgender_wikipedians.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 39
#      37 # Collecter les contributeurs des trois catégories
#      38 female_wikipedians = get_wikipedians_by_category("Female_Wikipedians")
# ---> 39 male_wikipedians = get_wikipedians_by_category("Male_Wikipedians")
#      40 transgender_wikipedians = get_wikipedians_by_category("Transgender_Wikipedians")
#      42 # Affichage des résultats (10 premiers contributeurs pour chaque catégorie)
#
# Cell In[2], line 31, in get_wikipedians_by_category(category_name)
#      28             elif member.ns == wikipediaapi.Namespace.CATEGORY:
#      29                 process_category(member)
# ---> 31     process_category(category)
#      32 else:
#      33     print(f"La catégorie {category_name} n'existe pas.")
#
# Cell In[2], line 23, in get_wikipedians_by_category.<locals>.process_category(cat)
#      22 def process_category(cat):
# ---> 23     for member in cat.categorymembers.values():
#      24         # Si la page est un utilisateur, on l'ajoute
#      25         if member.ns == wikipediaapi.Namespace.USER:
#      26             wikipedians.append(member.title)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\wikipediaapi\__init__.py:1060, in WikipediaPage.categorymembers(self)
#    1049 """
#    1050 Returns all pages belonging to the current category.
#    1051
#    (...)
#    1057 :return: :class:`PagesDict`
#    1058 """
#    1059 if not self._called["categorymembers"]:
# -> 1060     self._fetch("categorymembers")
#    1061 return self._categorymembers
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\wikipediaapi\__init__.py:1065, in WikipediaPage._fetch(self, call)
#    1063 def _fetch(self, call) -> "WikipediaPage":
#    1064     """Fetches some data?."""
# -> 1065     getattr(self.wiki, call)(self)
#    1066     self._called[call] = True
#    1067     return self
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\wikipediaapi\__init__.py:515, in Wikipedia.categorymembers(self, page, **kwargs)
#     513 while "continue" in raw:
#     514     params["cmcontinue"] = raw["continue"]["cmcontinue"]
# --> 515     raw = self._query(page, params)
#     516     v["categorymembers"] += raw["query"]["categorymembers"]
#     518 return self._build_categorymembers(v, page)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\wikipediaapi\__init__.py:529, in Wikipedia._query(self, page, params)
#     527 params["format"] = "json"
#     528 params["redirects"] = 1
# --> 529 r = self._session.get(base_url, params=params, **self._request_kwargs)
#     530 return r.json()
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Ismael\AppData\Local\Programs\Python\Python310\lib\ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import wikipediaapi  # API pour accéder à Wikipedia
import pandas as pd  # Pour structurer les données
import requests
import time
import re
import urllib.parse

# Initialisation de l'API Wikipedia avec un User-Agent personnalisé
user_agent = "GenderAnalysisProject/1.0 (contact@example.com)"  # Remplacez par votre email ou URL de contact
wiki = wikipediaapi.Wikipedia(language='en', user_agent=user_agent)  # Langue: anglais

# Liste des langues à explorer
languages = ['en', 'fr', 'de', 'es', 'it', 'ru', 'ja', 'zh']

# Fonction pour explorer une catégorie et ses sous-catégories pour obtenir les pages d'utilisateurs
def get_wikipedians_by_category(category_name):
    """
    Récupère une liste de contributeurs Wikipedia à partir d'une catégorie donnée, en parcourant les sous-catégories.
    :param category_name: Nom de la catégorie (par exemple, 'Female Wikipedians')
    :return: Liste des contributeurs
    """
    category = wiki.page(f"Category:{category_name}")
    wikipedians = []

    if category.exists():
        def process_category(cat):
            for member in cat.categorymembers.values():
                # Si la page est un utilisateur, on l'ajoute
                if member.ns == wikipediaapi.Namespace.USER:
                    username = member.title
                    # Supprimer le préfixe "User:" s'il est présent
                    if username.startswith('User:'):
                        username = username[len('User:'):]
                    username = username.strip()  # Supprimer les espaces superflus
                    wikipedians.append(username)
                # Si c'est une sous-catégorie, on la traite récursivement
                elif member.ns == wikipediaapi.Namespace.CATEGORY:
                    process_category(member)

        process_category(category)
    else:
        print(f"La catégorie {category_name} n'existe pas.")

    return wikipedians

# Collecter les contributeurs des trois catégories
female_wikipedians = get_wikipedians_by_category("Female_Wikipedians")
male_wikipedians = get_wikipedians_by_category("Male_Wikipedians")
transgender_wikipedians = get_wikipedians_by_category("Transgender_Wikipedians")

# Fonction pour extraire la localisation depuis le contenu de la page utilisateur
def extract_location_from_content(content):
    patterns = [
    r'\{\{\s*[Uu]ser location\s*\|\s*([^}|]+)',                    # {{User location|Location}}
    r'\{\{\s*[Uu]tilisateur\s*[Ll]ocalité\s*\|\s*([^}|]+)',        # {{Utilisateur Localité|Location}}
    r'This user lives in\s*[:]*\s*(.*?)\.',                        # "This user lives in: Location."
    r'This user lives in the\s*[:]*\s*(.*?)\.',                    # "This user lives in: Location."
    r'This user is from\s*[:]*\s*(.*?)\.',                         # "This user is from: Location."
    r'This user resides in\s*[:]*\s*(.*?)\.',                      # "This user resides in: Location."
    r'This user comes from\s*[:]*\s*(.*?)\.',                      # "This user comes from: Location."
    r'This user is located in\s*[:]*\s*(.*?)\.',                   # "This user is located in: Location."
    r'This user was born in\s*[:]*\s*(.*?)\.',                     # "This user was born in: Location."
    r'This user is living in\s*[:]*\s*(.*?)\.',                    # "This user is living in: Location."
    r'I (?:live|am from|come from|reside in|was born in|am located in)\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',  # "I live in: Location"
    r'My location is\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',              # "My location is: Location"
    r'Resides in\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',                  # "Resides in: Location"
    r'From\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',                        # "From: Location"
    r'Based in\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',                    # "Based in: Location"
    r'Living in\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',                   # "Living in: Location"
    r'Born in\s*[:]*\s*(.*?)\s*(?:\.|,|\n|$)',                     # "Born in: Location"
    r'Home\s*[:=]\s*(.*?)\s*(?:\.|,|\n|$)',                        # "Home: Location" ou "Home = Location"
    r'Location\s*[:=]\s*(.*?)\s*(?:\.|,|\n|$)',                    # "Location: Location" ou "Location = Location"
    r'Country\s*[:=]\s*(.*?)\s*(?:\.|,|\n|$)',                     # "Country: Location" ou "Country = Location"
    r'City\s*[:=]\s*(.*?)\s*(?:\.|,|\n|$)',                        # "City: Location" ou "City = Location"
    r'\{\{\s*[Uu]ser\s*[Gg]eolocation\s*\|\s*(.*?)\s*\}\}',        # {{User Geolocation|Location}}
    r'\{\{\s*[Uu]serbox\s*\|\s*location\s*=\s*(.*?)\s*\}\}',       # {{Userbox|location=Location}}
    r'\{\{\s*[Uu]ser\s*[Ll]ocation\s*\|\s*(.*?)\s*\}\}',           # {{User Location|Location}}
    r'\{\{\s*[Uu]ser\s*[Ff]rom\s*\|\s*(.*?)\s*\}\}',               # {{User From|Location}}
    r'\|\s*country\s*=\s*(.*?)\s*(?:\||\n)',                       # "| country = Location"
    r'\|\s*location\s*=\s*(.*?)\s*(?:\||\n)',                      # "| location = Location"
    r'\|\s*residence\s*=\s*(.*?)\s*(?:\||\n)',                     # "| residence = Location"
    r'\|\s*hometown\s*=\s*(.*?)\s*(?:\||\n)',                      # "| hometown = Location"
    r'==\s*Location\s*==\s*(.*?)\s*(?:==|\n\n)',                   # "== Location == Location information"
    r'\{\{\s*[Bb]abel\s*\|\s*(.*?)\}\}',                           # {{Babel|...|Location}}
    r'\{\{\s*[Uu]ser\s*[Mm]aps\s*\|\s*(.*?)\s*\}\}',               # {{User Maps|Location}}
]


    for pattern in patterns:
        match = re.search(pattern, content, re.IGNORECASE)
        if match:
            location = match.group(1).strip()
            # Nettoyage de la localisation pour enlever les balises ou les caractères spéciaux
            location = re.sub(r'<.*?>', '', location)
            location = re.sub(r'\[\[|\]\]', '', location)
            location = location.split('|')[0].strip()
            return location
    return "Unknown"

# Fonction pour obtenir la localisation de l'utilisateur
def get_user_location(username, lang='en'):
    username_encoded = urllib.parse.quote(username)
    url_user = f"https://{lang}.wikipedia.org/w/api.php"
    params_user = {
        "action": "query",
        "titles": f"User:{username_encoded}",
        "prop": "revisions",
        "rvprop": "content",
        "format": "json",
        "formatversion": "2"
    }

    try:
        response_user = requests.get(url_user, params=params_user)
        if response_user.status_code == 200:
            data_user = response_user.json()
            pages = data_user.get('query', {}).get('pages', [])
            for page in pages:
                if 'revisions' in page:
                    content = page['revisions'][0].get('content', '')
                    location = extract_location_from_content(content)
                    if location != "Unknown":
                        return location
    except Exception as e:
        print(f"Erreur lors de la récupération de la localisation pour {username} en {lang}: {e}")
    return "Unknown"

# Fonction pour obtenir les contributions d'un utilisateur
def get_user_contributions(username, limit=20):
    contributions = []
    username_encoded = urllib.parse.quote(username)
    for lang in languages:
        url_contrib = f"https://{lang}.wikipedia.org/w/api.php"
        params_contrib = {
            "action": "query",
            "list": "usercontribs",
            "ucuser": username_encoded,
            "uclimit": limit,
            "format": "json"
        }

        try:
            response_contrib = requests.get(url_contrib, params=params_contrib)
            if response_contrib.status_code == 200:
                data_contrib = response_contrib.json()
                if 'query' in data_contrib and 'usercontribs' in data_contrib['query']:
                    for contrib in data_contrib['query']['usercontribs']:
                        contributions.append({
                            "title": contrib['title'],
                            "timestamp": contrib['timestamp'],
                            "language": lang
                        })
            time.sleep(0.5)  # Pause pour éviter de surcharger les serveurs
        except Exception as e:
            print(f"Erreur lors de la récupération des contributions pour {username} en {lang}: {e}")
    return contributions

# Fonction pour collecter les contributions et la localisation par genre
def collect_contributions_and_location(wikipedians, gender):
    for user in wikipedians:
        username = user.strip()
        # Ignorer les utilisateurs suspects
        if '/' in username or len(username) == 0:
            print(f"Ignorer l'utilisateur suspect: {username}")
            continue
        print(f"Traitement de l'utilisateur: {username}")

        # Obtenir la localisation (par défaut en anglais)
        region = get_user_location(username, lang='en')
        print(f"Localisation trouvée: {region}")

        # Obtenir les contributions de l'utilisateur
        contributions = get_user_contributions(username)
        print(f"Nombre de contributions trouvées: {len(contributions)}")

        for contrib in contributions:
            all_contributions.append({
                "User": username,
                "Title": contrib['title'],
                "Timestamp": contrib['timestamp'],
                "Gender": gender,
                "Language": contrib.get('language', 'unknown'),
                "Region": region if region else 'unknown'
            })
        # Délai pour éviter de surcharger les serveurs de Wikipédia
        time.sleep(1)

# Liste pour stocker toutes les contributions avec la localisation
all_contributions = []

# Collecter les contributions et la localisation pour chaque genre
collect_contributions_and_location(female_wikipedians[:300], 'Female')
collect_contributions_and_location(male_wikipedians[:300], 'Male')
collect_contributions_and_location(transgender_wikipedians[:300], 'Transgender')

# Créer un DataFrame avec toutes les contributions
df_contributions = pd.DataFrame(all_contributions)

# Sauvegarder les données dans un fichier CSV
df_contributions.to_csv("wikipedia_contributions_with_geography5.csv", index=False)

# Afficher les premières lignes du DataFrame
print(df_contributions.head())
# Out:
# Traitement de l'utilisateur: !hauntaholics
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: .huepow
# Localisation trouvée: United States
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: .pixiedzt
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 1
# Traitement de l'utilisateur: *Mikaplayz17*
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: *Yukio Okumura*
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: $ugar$weet
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 0xF8E8
# Localisation trouvée: Providence
# Nombre de contributions trouvées: 48
# Traitement de l'utilisateur: 1Krystal.Stevens
# Localisation trouvée: Winchester
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: 2Cute4U
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 2nights
# Localisation trouvée: February}}
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3loodlust
# Localisation trouvée: Texas}}
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 5 albert square
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 5deadlydaisies
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 6-6-6
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 7
# Traitement de l'utilisateur: 7o2sLibrary
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 10
# Traitement de l'utilisateur: 9Doors
# Localisation trouvée: Canada
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 16pedia2
# Localisation trouvée: friends and relatives)   French language
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 19user99
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: 20-13-rila
# Localisation trouvée: morning shower to school to nighttime yawns in an imagined world of ''if only'' Star Wars style
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 27yearsofmagic
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 50shadesofweird
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: 50shadesofweird/sandbox
# Traitement de l'utilisateur: 60 Delta
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 90summerchild
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 99Ferrari
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 2012An(4thwm1)
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 2013creek
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 2511GNQ
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 9848hhmhhm
# Localisation trouvée: China}}File:20090426 5223 Shanghai JinMao SWFC
# Nombre de contributions trouvées: 25
# Traitement de l'utilisateur: 8238245424nayna
# Localisation trouvée: India
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: 9879248233tabu
# Localisation trouvée: India
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: A
# Localisation trouvée: Vietnam
# Nombre de contributions trouvées: 70
# Traitement de l'utilisateur: A cardboard microwave
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: A Highway Got Paved Over My Future, I Drive It Getting to School
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: A.J.V.
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 10
# Traitement de l'utilisateur: A.sky245
# Localisation trouvée: en-5
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: A20anna
# Localisation trouvée: '''California'''
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aanapk
# Localisation trouvée: Multan
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Abbey kershaw
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Abbie.dodz
# Localisation trouvée: Kingston
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Abby724
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: Abbyfluoroethane
# Localisation trouvée: Norman
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: Abcassionchan/Userboxes
# Traitement de l'utilisateur: Abchave1
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AbigailAbernathy
# Localisation trouvée: leaving a message to said user; the less ruckus
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: Abigailxdawson02
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: Ablaine2
# Localisation trouvée: Fredericksburg
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Abluescarab
# Localisation trouvée: near Portland
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: ABShipper
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Abstractedly
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ac132022
# Localisation trouvée: Scotland
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Acal26
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Acarr2
# Localisation trouvée: Chicago
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Accireioj
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AccountableJune
# Localisation trouvée: other languages  Mainly interested in articles about LGBTQ+ people and women
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Accurate Pro
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Achirpingbird
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Acplatt87
# Localisation trouvée: Surrey
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: ACrockford
# Localisation trouvée: July 2013 - April 2015 I was the Wikipedian in Residence
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: Acyos
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Adaobi
# Localisation trouvée: my contributions - it's been decaying exponentially rather quickly
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: Addojammo
# Localisation trouvée: en
# Nombre de contributions trouvées: 18
# Traitement de l'utilisateur: Adecember16
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adept primae
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aderangedhyena
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Adevish
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 26
# Traitement de l'utilisateur: Adevv
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Adina12341
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 7
# Traitement de l'utilisateur: Adreamtonight
# Localisation trouvée: en-5
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adrelliea
# Localisation trouvée: Boston
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adriana Sanchez Ramirez
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Adriana-Corina
# Localisation trouvée: Alone (TV series)
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adriana513
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 64
# Traitement de l'utilisateur: Adrianpauw
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adrienne4lyfe
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Adventuretimer1
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Advjuvairianv
# Localisation trouvée: '''Kerala''' - God%27s_Own_Country#Kerala
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aebcoreno
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AEE8895
# Localisation trouvée: Glasgow
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aeforee
# Localisation trouvée: Indonesian-Australian mother and Chinese-Australian father in Lismore
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aelita@Lyoko
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aelita14
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 47
# Traitement de l'utilisateur: Aelyanariah
# Localisation trouvée: Anchorage
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ænea
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aepowell122
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aeris211
# Localisation trouvée: Nashville
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AeroDreamy
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Af1120
# Localisation trouvée: a research paper for Uni
# Nombre de contributions trouvées: 18
# Traitement de l'utilisateur: Afddiary
# Localisation trouvée: in Deep South
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AffirmationChick
# Localisation trouvée: California Baptist University
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Afrodita nz
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Agampa
# Localisation trouvée: education
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: AgentKaz
# Localisation trouvée: NY}}
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Agentul portocaliu
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Agne27
# Localisation trouvée: people smarter than me==
# Nombre de contributions trouvées: 26
# Traitement de l'utilisateur: Agnyeszka
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Aharri29
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aharriot96
# Localisation trouvée: the Memorial University of Newfoundland
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ahartlin
# Localisation trouvée: St
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aidanpie
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: Aidenlockhart
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 15
# Ignorer l'utilisateur suspect: Aikia08/sandbox
# Traitement de l'utilisateur: AimeeSunflower
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aina Aiikyo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Airajuliafor
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aisha uk
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aislingodonnell
# Localisation trouvée: Exeter
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: Aizhen
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: AJ9/Userpage
# Traitement de l'utilisateur: AjaaniSherisu
# Localisation trouvée: en
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Ajdrosario
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ajfweb
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 56
# Traitement de l'utilisateur: Ajk1962f
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ajoust
# Localisation trouvée: ?  File:Canon EOS 400D 9506
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aking27
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Akke Bandvagn
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Akonkia
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: Akramm
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 64
# Traitement de l'utilisateur: AlabasterCarnation
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 15
# Traitement de l'utilisateur: Alagaesia dragon
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Alakazaamm
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alama~enwiki
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Alammana
# Localisation trouvée: en-5
# Nombre de contributions trouvées: 29
# Traitement de l'utilisateur: Alannah.Marsh
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Alawya
# Localisation trouvée: King Saud University- Saudi Arabia and I have a MS in Information Science from University of Pittsburgh
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Alaynakrantz
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alec Elswit
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: AlecsisJ
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Lady Aleena
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aleksd
# Localisation trouvée: Sofia
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alexandra.Hornbach.1
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alexandraasa95
# Localisation trouvée: Focșani
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlexandraAVX
# Localisation trouvée: Malmö
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: Alexie
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alexis.charles
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlexplayzWIKI
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Alexpsihogios
# Localisation trouvée: parent to child)
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alexshmalex
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlextheGreat41
# Localisation trouvée:
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: Alfirin
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: Alfonsoneri
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Algillespy
# Localisation trouvée: Davidson
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: Ali K
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Aliaaalhsane
# Localisation trouvée: 2012 till 2016
# Nombre de contributions trouvées: 1
# Ignorer l'utilisateur suspect: BushelCandle/About Me
# Traitement de l'utilisateur: Alice Lee
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Alicecooper91
# Localisation trouvée: stub
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aliceinthealice
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlicexCullen
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AliciaBanks1994
# Localisation trouvée: Liverpool
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Alicialynn4
# Localisation trouvée: North Dakota
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: Alicja11willow
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlienvsEditor
# Localisation trouvée:
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlinaGusewa
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 74
# Traitement de l'utilisateur: Alinedomingo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Alison.m.carlson.2
# Localisation trouvée: North Dakota
# Nombre de contributions trouvées: 7
# Ignorer l'utilisateur suspect: Alissa.gordon/sandbox
# Traitement de l'utilisateur: Alixmpier
# Localisation trouvée: New Jersey
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alixos
# Localisation trouvée: on unceded Kaurna country and acknowledge Elders past and present
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Allamune
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AllArtAfterAll
# Localisation trouvée: de
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: Allecher
# Localisation trouvée: the last 10 years
# Nombre de contributions trouvées: 35
# Traitement de l'utilisateur: Allforkatery
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Allicjia
# Localisation trouvée: Opole
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alliephenix99
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 26
# Traitement de l'utilisateur: Allimarieb
# Localisation trouvée: Utah
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Allison M
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Allison.j.morse
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AllisonFoley
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Allisonmontgomery69
# Localisation trouvée: '''South Dakota'''
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AllureOfTheEarth
# Localisation trouvée: Richmond Hill
# Nombre de contributions trouvées: 16
# Traitement de l'utilisateur: Ally525
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Allypat
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: Allyrmartin
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Allyrosa
# Localisation trouvée: in Brussels
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Almafeta
# Localisation trouvée: 23 February 2006 and prior were removed from the GFDL
# Nombre de contributions trouvées: 50
# Traitement de l'utilisateur: Almeta
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AlphaZelda
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alwaysjustthatgirl
# Localisation trouvée: in North Carolina and am a female Asian American user on Wikipedia
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyandra
# Localisation trouvée: a sleepy small village in Switzerland
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssa-Burley
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssa.j.anderson
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssa.wroblewski
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssabelle818
# Localisation trouvée: the small town of Plainville
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssagoodpaster
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Alyssalansing
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Alyx24
# Localisation trouvée:
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: Amagwy
# Localisation trouvée: in Seattle
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amal Selmi
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amanda Fern.
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amanda Pachal
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amanda.krebs
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amandabdaly
# Localisation trouvée: Vermont
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: AmandaKraha
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: Amandaladucer
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amandaprefect
# Localisation trouvée: Essex
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmandaSLawrence
# Localisation trouvée: 19 July 2021-2022 I wasWikipedian in residence
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmandaWins
# Localisation trouvée: es-4
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amarinucci16
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amaryllis25
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmazinVenezuelan
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amber Fortuno
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amberdee3
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmberDN
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ambicide
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: Ambrose01
# Localisation trouvée: Bruges
# Nombre de contributions trouvées: 18
# Traitement de l'utilisateur: Ambrosia10
# Localisation trouvée: in Wellington
# Nombre de contributions trouvées: 28
# Traitement de l'utilisateur: Ame Kyaw
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amedresearcher
# Localisation trouvée: Highland Heights
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Amedyr
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amekyras
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmeliaUS
# Localisation trouvée: Kiev
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: American che
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amesdeutsch
# Localisation trouvée: Canada
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amf14
# Localisation trouvée: St
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmiriteC
# Localisation trouvée:
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amoxicillin on a Boat
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Amran.aden
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: Amulet Heart/infobox2
# Traitement de l'utilisateur: Amuseclio
# Localisation trouvée: Clio
# Nombre de contributions trouvées: 55
# Traitement de l'utilisateur: Amy.duchene
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amy18391
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amyamy1990922
# Localisation trouvée: Pittsburgh
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: Amyanda2000
# Localisation trouvée: John Lennon
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amydonovan15
# Localisation trouvée: Edinburgh Castle
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amyekankiewicz
# Localisation trouvée: Provo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AmyTAllen
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Amzi
# Localisation trouvée: Inner Mongolia
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: An girl with one grammatical error
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: An Oddian
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Ana Cooke
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Ana Radic
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Anacaona
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: Anafar
# Localisation trouvée: en
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: Anagonzalez
# Localisation trouvée: es
# Nombre de contributions trouvées: 24
# Traitement de l'utilisateur: Anaisfirewalkwithme
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Anamika Vishwakarma 10
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Ananga
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Anatashala
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Anawiski
# Localisation trouvée: my last name and part of my first name
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Ancazur
# Localisation trouvée: user:Dan128
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AndiWheeler
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: André the Android
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Andrea Parton
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Andrea-M0
# Localisation trouvée: el
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Andreabocincova
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Andrealisahoch
# Localisation trouvée: New Brunswick
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: AndreaPersephone
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Andreasmperu
# Localisation trouvée: es-N
# Nombre de contributions trouvées: 105
# Traitement de l'utilisateur: Andrenglish
# Localisation trouvée: Göteborg
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Anelso
# Localisation trouvée: St Peter
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Aneteen
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: Ang li
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Angel Rolls
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Angela26
# Localisation trouvée: in Sydney
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: Angela21124/About me
# Traitement de l'utilisateur: Angelasong
# Localisation trouvée: en
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: AngelOfSadness
# Localisation trouvée: Dublin
# Nombre de contributions trouvées: 25
# Traitement de l'utilisateur: Angie Y.
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Angie.Scott
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Angie&Tom
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Angie~enwiki
# Localisation trouvée: animal shelter}}
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Angiebcn89
# Localisation trouvée: Barcelona
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Angiez628
# Localisation trouvée: Pittsburgh
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: AniBunny
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 26
# Traitement de l'utilisateur: Animalgaura
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: Aninush
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 17
# Traitement de l'utilisateur: Anirie Ké
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Anishagupta
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 13
# Traitement de l'utilisateur: Anita francis2504
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: AnitaConchita
# Localisation trouvée: time to time
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: AnkitaDatta11
# Localisation trouvée: bn
# Nombre de contributions trouvées: 36
# Traitement de l'utilisateur: Anna jurgens
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Anna L. Black
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Anna St.Onge
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Anna.Gluchowska
# Localisation trouvée: Lublin
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: AnnaBeiyan
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 29
# Traitement de l'utilisateur: AnnabelleVS
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: Annainformationfree
# Localisation trouvée: '''Greece''' and is a '''Greek Orthodox Church
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: AnnaKucsma/Userboxes
# Traitement de l'utilisateur: AnnaMarie31
# Localisation trouvée: Glasgow
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Annamaur
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 9
# Traitement de l'utilisateur: Annasteidle
# Localisation trouvée: Chemnitz
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Annazhigareva
# Localisation trouvée: Scotland}}
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: AnnaZZZ
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Anne 14
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: AnneD17
# Localisation trouvée: Coral Gables
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Annette fleming
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Annetteruiz
# Localisation trouvée: Fargo
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Annettet
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: Annie E. Clarke
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Annie333
# Localisation trouvée: en
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: AnnieHall
# Localisation trouvée: Midland
# Nombre de contributions trouvées: 24
# Traitement de l'utilisateur: AnnieK
# Localisation trouvée: New York (state)
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Annukii
# Localisation trouvée: in Perth
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Annwnsystem
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Anotaomo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Anthere
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 135
# Ignorer l'utilisateur suspect: Anthere/About
# Traitement de l'utilisateur: Antholor
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Ignorer l'utilisateur suspect: Kirananils/Templates/User Male
# Traitement de l'utilisateur: - LeLo -
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Ignorer l'utilisateur suspect: -andreas/Infobox
# Traitement de l'utilisateur: -Bobby
# Localisation trouvée: this lucky introduction
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: -Chiyo-Mihama-
# Localisation trouvée: my favorite anime and there really is no male charecters in that show except for Kimura
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: -Haryad
# Localisation trouvée: slemani
# Nombre de contributions trouvées: 11
# Traitement de l'utilisateur: -iNu-
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 91
# Ignorer l'utilisateur suspect: -Ozone-/Userboxes
# Traitement de l'utilisateur: -Zai-
# Localisation trouvée: United States
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: !xowAT4Z3Q
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: ?uest
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Ignorer l'utilisateur suspect: ?uest/Infobox
# Ignorer l'utilisateur suspect: ?uest/Main userboxes
# Ignorer l'utilisateur suspect: ?uest/Userboxes
# Traitement de l'utilisateur: 凰兰时罗
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: .edu.edits
# Localisation trouvée: institutions
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: "greenzig"
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: (aeropagitica)
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Ignorer l'utilisateur suspect: (aeropagitica)/userboxes
# Traitement de l'utilisateur: **dave**
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: *Sam*
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: \\'arrior 786
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: \RodneyCheesefather
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: +RaNdOm NwS+
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: +SPQR
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: ~~DanWL60~~
# Localisation trouvée: Gwynedd
# Nombre de contributions trouvées: 25
# Traitement de l'utilisateur: ~Ryan Mckenzie~
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: ~Viper~
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Tonkarooson
# Localisation trouvée: editing it on September 27
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: $cammer
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 0 Shibbir Ahmed
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 00Penguin00
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 13
# Traitement de l'utilisateur: 0rsted
# Localisation trouvée: Metropolitan Copenhagen with my Wife and our Cat
# Nombre de contributions trouvées: 9
# Traitement de l'utilisateur: 0TomSmith
# Localisation trouvée: Great Britain
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 0xCBG
# Localisation trouvée: Seattle
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: 1 of 8
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 1AmNobody24
# Localisation trouvée: =01 April 2023
# Nombre de contributions trouvées: 42
# Ignorer l'utilisateur suspect: 1bookfan/userboxes
# Traitement de l'utilisateur: 1bunty1
# Localisation trouvée: Bhubaneswar
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 1c33y37
# Localisation trouvée: this
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 1ctinus
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: 1hp buddu
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 01iproject09
# Localisation trouvée: '''ISRAEL'''
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 1kAnden N24
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 1Kwords
# Localisation trouvée: _the_welfare_state_to_the_caliphate_sweden_islamic_state_syria_iraq_foreign_fighters/
# Nombre de contributions trouvées: 60
# Traitement de l'utilisateur: 01satkins
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 10
# Traitement de l'utilisateur: 1Sire
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 42
# Traitement de l'utilisateur: 1Skywriter
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 1theKs
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: 1TherealGamebøy6567
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 1Winston
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 2 Lit 2 Late
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Ignorer l'utilisateur suspect: 02barryc/bodytable
# Ignorer l'utilisateur suspect: 02barryc/userbox
# Ignorer l'utilisateur suspect: 02barryc/Userboxtable
# Traitement de l'utilisateur: 2jak2jaked
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 15
# Traitement de l'utilisateur: 2much
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 2NumForIce
# Localisation trouvée: library/public computers
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 2taha7
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3.14159265459AAAs
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3ephs
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3family6
# Localisation trouvée: Lanesborough
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: 3Good5Me
# Localisation trouvée: United States
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: 3H
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3KnoWell
# Localisation trouvée: United States
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: 3l $3rgi0
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 3mgrant
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3mixMn
# Localisation trouvée: Mongolia
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: 3mjccjmcj
# Localisation trouvée: the Americas}}
# Nombre de contributions trouvées: 1
# Traitement de l'utilisateur: 3OpenEyes
# Localisation trouvée: a very cold area)
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 3PPYB6
# Localisation trouvée: User:CapLiber
# Nombre de contributions trouvées: 62
# Ignorer l'utilisateur suspect: 3PPYB6/sandbox4
# Traitement de l'utilisateur: 3RDRANGER
# Localisation trouvée: Canada
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 3wing93
# Localisation trouvée: Hampton
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: 004.Berni.B
# Localisation trouvée: 01/01/1974 till:01/02/1975
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: 4myself4/UB
# Traitement de l'utilisateur: 4PeterMax
# Localisation trouvée: conlangs such as Toki Pona or Solresol
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 4spring
# Localisation trouvée: de
# Nombre de contributions trouvées: 35
# Traitement de l'utilisateur: 4TheWynne
# Localisation trouvée: in Melbourne
# Nombre de contributions trouvées: 40
# Ignorer l'utilisateur suspect: 4v4l0n42/Boxes
# Ignorer l'utilisateur suspect: 5aret/5aret's userboxes2
# Traitement de l'utilisateur: 5ch120
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 5faizan
# Localisation trouvée: in Hyderabad
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: 5faizan/userboxes
# Traitement de l'utilisateur: 6feetunderjoe
# Localisation trouvée: loving to travel and eat different varieties ofasian and mediterenian cuisine
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 6ii9
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 101
# Traitement de l'utilisateur: 07 Matthew
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 7D HMS
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 7Eleven99Swell
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 43
# Traitement de l'utilisateur: 7even.up
# Localisation trouvée: Serbia
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 007fan28
# Localisation trouvée: Illinois and only lived there for  the first 4 years of my life
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 07Hawk
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: 7heGame
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 7partparadigm
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 7R7
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 7th Arc
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Ignorer l'utilisateur suspect: 8en/Templates/Userinfo
# Traitement de l'utilisateur: 8isthemagicnumber
# Localisation trouvée:
# Nombre de contributions trouvées: 19
# Traitement de l'utilisateur: 08murtaghkc
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 8qblog
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 9mm.trilla
# Localisation trouvée: in CA
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 10mandown
# Localisation trouvée: Juiz de Fora
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 10MB
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 11JORN
# Localisation trouvée: 0
# Nombre de contributions trouvées: 77
# Traitement de l'utilisateur: 12candyapple
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 12cool725
# Localisation trouvée: Futurama)
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 14GTR
# Localisation trouvée: Moldova
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: 14kb93
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: 15turnsm
# Localisation trouvée: Melbourne
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 016iman
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 18BoldSpil89
# Localisation trouvée: Bosnia and Herzegovina
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 19 minutes
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 21stCenturyGreenstuff
# Localisation trouvée: and lived in '''Birmingham'''
# Nombre de contributions trouvées: 33
# Traitement de l'utilisateur: 22pandrew
# Localisation trouvée: now on
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 27Hippos
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: 27JJ
# Localisation trouvée: Toronto
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 30scorp
# Localisation trouvée: India
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 38chad
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 48Lugur
# Localisation trouvée: Fresno
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: 49p
# Localisation trouvée: location parameter -->
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 53
# Localisation trouvée: User:Bmf 051 and User:Kithira/Stadia
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: 57 slimshady
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: 59RY
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 43
# Traitement de l'utilisateur: 65HCA7
# Localisation trouvée: people sometimes
# Nombre de contributions trouvées: 30
# Traitement de l'utilisateur: 66seals
# Localisation trouvée: various IP addresses and have recently created this account in order to keep track of my changes and to follow changes made to pages on my watchlist
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 77Survivor
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: 84denniswong
# Localisation trouvée: HKU
# Nombre de contributions trouvées: 43
# Traitement de l'utilisateur: 84singh84
# Localisation trouvée:
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 89Fresh
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 90ozjugofdiarrhea
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 16
# Traitement de l'utilisateur: 90sdude
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: 95jb14/Userboxes
# Traitement de l'utilisateur: 97GeoPrizm
# Localisation trouvée: en
# Nombre de contributions trouvées: 39
# Traitement de l'utilisateur: 99hgbh
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 99Moriarty
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 6
# Traitement de l'utilisateur: 100.undentifieduser
# Localisation trouvée: Portuguese Wikipedia
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: 100garrixer
# Localisation trouvée: Hilversum
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: 102Legobrick
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 102RB
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 122
# Traitement de l'utilisateur: 108nityananda
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: 111TeamDynamo111
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 9
# Ignorer l'utilisateur suspect: 114BryanKurt/Userboxes
# Traitement de l'utilisateur: 117Avenue
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 130
# Traitement de l'utilisateur: 123ad
# Localisation trouvée: Chester
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 123kid
# Localisation trouvée: Gold Coast
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: 123oscar21
# Localisation trouvée: Delhi
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: 123ryan12
# Localisation trouvée: Delhi
# Nombre de contributions trouvées: 1
# Traitement de l'utilisateur: 123w456t
# Localisation trouvée: Unknown
# ...
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: DuctTapeEnthusiast
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 9
# Traitement de l'utilisateur: Dudhhr
# Localisation trouvée: United States
# Nombre de contributions trouvées: 35
# Traitement de l'utilisateur: Eatingbugs
# Localisation trouvée: Earth}}
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: EatYourHashs
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: EChemistryHub
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: EconomicDose
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: EldritchEmpress
# Localisation trouvée: en-4
# Nombre de contributions trouvées: 31
# Traitement de l'utilisateur: ElerosV
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Elida Rubielle (Astradia)
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: ElizabethIsAlive
# Localisation trouvée: United States
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ellagabalus
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Emars1
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 10
# Traitement de l'utilisateur: Emiliasamanthaalexismadrigal
# Localisation trouvée: animal shelter}} {{User:Basketball110/Endanger}} {{User all animals
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Emma Caroline
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: EmmaIsTemporary
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: EurovisionAndXenomorphs
# Localisation trouvée: Knowhere==
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: ExplodingPoPUps
# Localisation trouvée: align=right
# Nombre de contributions trouvées: 33
# Traitement de l'utilisateur: Ezeva
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Fauxey
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Felineum
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: FenrisAureus
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: FenrisAureus/UBX/personal-info
# Traitement de l'utilisateur: Feralcateater000
# Localisation trouvée: the Wiki
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Fernmyne
# Localisation trouvée: article in Spanish)
# Nombre de contributions trouvées: 25
# Traitement de l'utilisateur: FezEmerald
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Findanegg
# Localisation trouvée: Chicago
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: FireDragonValo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 160
# Ignorer l'utilisateur suspect: Fishesfillet/Userboxes
# Traitement de l'utilisateur: Flfitz
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: Fluffycritter
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Fodla'sSecond
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Foobie bletch
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: ForestJay
# Localisation trouvée: w:Fitchburg
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: FoxLacy
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 7
# Traitement de l'utilisateur: Foxtdev
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: FracaWicro
# Localisation trouvée: my userboxes
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Freyaxoxo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 5
# Traitement de l'utilisateur: Frostcrush Valari
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Ftmichael
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: FunksBrother
# Localisation trouvée: en
# Nombre de contributions trouvées: 45
# Traitement de l'utilisateur: Furbyfan4lyf
# Localisation trouvée: United States
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Gargargarrick
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Gatorboi420
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Gearhead1975
# Localisation trouvée: childhood's hour this user has not been as others were
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: GearheadLydia
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: GearheadLydia/more userboxes
# Traitement de l'utilisateur: Gerfried Fuchs~enwiki
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Ghost finders
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: GloriousGalaxyGal
# Localisation trouvée: en
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Glurie
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Gnossospappadopoulis
# Localisation trouvée: Massachusetts}}{{User:Queerly Bohemian/Userboxes/Countercultureofthe1960s}}{{User:Cegalegolog99/userboxes/c&h}}{{User:Jerem43/ubx-yankees}}{{Template:User camping}}{{User semicolon}}{{User:CanonLawJunkie/Userboxes/No Modern Notation}}{{User:MQDuck/userboxes/Legalization}}{{User:Electriceel/Userboxes/Tattooed 1}}{{Template:User eccentric}}{{User:UBX/fishy}}{{User:Audacity/Userboxes/Hip hop}}{{User:UBX/Stealie}}{{User:Life in General/Userboxes/AntiMilitarist}}{{User:UBX/Indian cuisine}}{{User:UBX/Japanese cuisine}}{{User lastminute}}{{User:Ceedub88/Userboxes/A Tribe Called Quest 5}}{{User:BrokenSphere/Userboxes/Biggie}}{{User:BrokenSphere/Userboxes/2Pac}}{{User:GWFrog/UBX/looney}}{{Wikipedia:WikiProject Scouting/Userboxes/GS}}{{User:Redfarmer/Vonnegut}}{{User:UBX/Joan Jett}}{{User likes soups}}{{User:Life in General/Userboxes/Supernatural}}{{User:The Dark Side/Original userboxes/Verne‎}}{{User in Wisconsin}}{{User:Kakofonous/UBX/Get On Up}}{{User:FormalDude/Userboxes/Police State}}{{User:Mtmelendez/Userboxes/Bob Dylan 3}}{{User Poison ivy sensitive}}
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: GoAnimateKingWAME
# Localisation trouvée: en
# Nombre de contributions trouvées: 2
# Traitement de l'utilisateur: Gogobobo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: Gogobobo/sandbox/Gogobobo
# Traitement de l'utilisateur: GoldenPenny
# Localisation trouvée: Brooklyn College with a Bachelor of Arts (B
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: GooberSchnarf
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Goobington
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Graveyardpansy
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: GrayMitchell
# Localisation trouvée: the earliest times to 2004
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Gupdoo3
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 27
# Traitement de l'utilisateur: Gwennie-nyan
# Localisation trouvée:
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Gwingle
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: HalmensNoKindaiTaiso
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 18
# Traitement de l'utilisateur: HarryPotter7777
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 8
# Traitement de l'utilisateur: Heather of Midgard
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Hejdd
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Heyallkatehere
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: HeyElliott
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Ignorer l'utilisateur suspect: HeyElliott/Userboxes
# Traitement de l'utilisateur: HFisch89
# Localisation trouvée: a few drive-by anonymous typo fixes I've done over the years)
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Hitoubashira
# Localisation trouvée: England}}
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Hoodus
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Hotdogsyrup
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: HotMess
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 24
# Traitement de l'utilisateur: HowToRuinEverything
# Localisation trouvée: in the suburbs of Milwaukee
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: Hydrangeans
# Localisation trouvée: ercules in gevecht met de hydra van Lerna
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Iatethecheese
# Localisation trouvée: the wikivamps
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Ichigoichigo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 30
# Traitement de l'utilisateur: IkuyoYumino
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 13
# Traitement de l'utilisateur: Ilovecats516
# Localisation trouvée: British Columbia on a mission to keep Wikipedia accurate and factual
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Immanuelle
# Localisation trouvée: the recent glut
# Nombre de contributions trouvées: 124
# Traitement de l'utilisateur: ImperialSaponification
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Indigobeam
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Infamously
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: InNicoTime
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 9
# Traitement de l'utilisateur: Inventorfrog
# Localisation trouvée: Wikipedia articles about the grammar of my target languages
# Nombre de contributions trouvées: 23
# Traitement de l'utilisateur: Invisiboy42293
# Localisation trouvée: United States
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: Irawhiti
# Localisation trouvée: Aotearoa New Zealand
# Nombre de contributions trouvées: 15
# Traitement de l'utilisateur: Isla
# Localisation trouvée:
# Nombre de contributions trouvées: 33
# Ignorer l'utilisateur suspect: Isla/userbox
# Traitement de l'utilisateur: Its.jxssica
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: ItsZippy23
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Jaminux
# Localisation trouvée: South Carolina}}
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Jazzboy19
# Localisation trouvée: New Hampshire}}{{User Buddhist}}
# Nombre de contributions trouvées: 3
# Traitement de l'utilisateur: JeanetteMartin
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 72
# Traitement de l'utilisateur: Jeh2ow
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Jemiamapus
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Jenaptrsn
# Localisation trouvée: the planet Earth
# Nombre de contributions trouvées: 10
# Traitement de l'utilisateur: Jennasloan
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: JenniferG
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 12
# Traitement de l'utilisateur: Jessica729
# Localisation trouvée: in the North East of England near Newcastle
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: JessRyanA
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: JINIPPYBASILE
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 7
# Traitement de l'utilisateur: JJPMaster
# Localisation trouvée: changing "Open-source software
# Nombre de contributions trouvées: 28
# Ignorer l'utilisateur suspect: JJPMaster/Userboxes
# Traitement de l'utilisateur: Jljsb
# Localisation trouvée: my Special:Contributions/79
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Johanna
# Localisation trouvée: 2014-2016 but took a long hiatus to focus on high school and then college
# Nombre de contributions trouvées: 34
# Traitement de l'utilisateur: Jojosunshine69
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 15
# Traitement de l'utilisateur: Jone425
# Localisation trouvée: en
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: Julesucks
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 14
# Traitement de l'utilisateur: JuliaLblnd
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 22
# Traitement de l'utilisateur: Justine Love Khloo
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Kait604
# Localisation trouvée: United States
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kanyoko
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 4
# Traitement de l'utilisateur: Kara Paravel
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: KaraLG84
# Localisation trouvée: the UK
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Katie Ryan A
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: Kawaii-Soft
# Localisation trouvée: childhood
# Nombre de contributions trouvées: 28
# Traitement de l'utilisateur: Kayne.amoureux
# Localisation trouvée: Washington
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kaythehistorian
# Localisation trouvée: File:Flag of Indonesia
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kegdr
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kelis98
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: KharBevNor
# Localisation trouvée: the United Kingdom
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kieraaaa
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 7
# Ignorer l'utilisateur suspect: Kieraaaa/Userboxes/Kiera
# Traitement de l'utilisateur: King of the froggies
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 0
# Traitement de l'utilisateur: KingForPA
# Localisation trouvée: the Wiki page for Rolling Acres Mall
# Nombre de contributions trouvées: 21
# Traitement de l'utilisateur: Kinopiko
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
# Traitement de l'utilisateur: Kiore
# Localisation trouvée: Auckland City
# Nombre de contributions trouvées: 40
# Traitement de l'utilisateur: Kithburd
# Localisation trouvée: Unknown
# Nombre de contributions trouvées: 20
#       User                 Title             Timestamp  Gender Language  \
# 0  .huepow  User:.huepow/sandbox  2022-12-31T23:56:24Z  Female       en
# 1  .huepow  User:.huepow/sandbox  2022-12-31T23:54:47Z  Female       en
# 2  .huepow  User:.huepow/sandbox  2022-12-31T23:36:36Z  Female       en
# 3  .huepow  User:.huepow/sandbox  2022-12-31T23:00:31Z  Female       en
# 4  .huepow  User:.huepow/sandbox  2022-12-31T07:30:31Z  Female       en
#
#           Region
# 0  United States
# 1  United States
# 2  United States
# 3  United States
# 4  United States
